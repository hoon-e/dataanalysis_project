# %%
import pandas as d
import csv
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize = (15,15))
# anal = d.read_csv('지역별병수.csv', names=['year', 'age', 'sub', 'gender', 'region', 'main_name', 'sub_name', 'main_code', 'sub_code'], sep=",", encoding="cp949")
rl = d.read_csv('의료인원수.csv', names=['region', 'ratio'], sep=',', encoding="cp949")
anal = d.read_csv('지역별병수.csv', names=['region', 'number'], sep=",", encoding="cp949")

anal = d.merge(anal, rl, on='region', how='left', sort=False)

sns.heatmap(data=anal.corr(), annot=True, fmt= '.2f', linewidths=.5, cmap='Reds')
